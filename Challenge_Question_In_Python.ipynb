# %% [markdown]
# <a href="https://colab.research.google.com/github/Anushka108/Challenge-Question-Using-Python/blob/main/Challenge_Question_In_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
L=["ram","shyam","aman",5,2,7,4]
L=[str(i) for i in L]
print(L)
L.sort()
print(L)
L1=[]
for i in L:
  try:
    L1.append(int(i))
  except:
      L1.append(i)
print(L1)
# Out:
# ['ram', 'shyam', 'aman', '5', '2', '7', '4']
# ['2', '4', '5', '7', 'aman', 'ram', 'shyam']
# [2, 4, 5, 7, 'aman', 'ram', 'shyam']

# %%
import time
t1=time.time()
for i in range(100000):
  for j in range(100000):
    x=900
    t2=time.time()
    print(t2-t1)
# Out:
# Streaming output truncated to the last 5000 lines.
# 70.02122235298157
# 70.02123641967773
# 70.02125096321106
# 70.02126550674438
# 70.02127957344055
# 70.02129364013672
# 70.02130770683289
# 70.02132177352905
# 70.02133584022522
# 70.02134966850281
# 70.02136421203613
# 70.02137804031372
# 70.02139163017273
# 70.02140522003174
# 70.02141904830933
# 70.0214331150055
# 70.02144742012024
# 70.02146172523499
# 70.02147555351257
# 70.02148938179016
# 70.02150297164917
# 70.02151679992676
# 70.02153038978577
# 70.02154421806335
# 70.02155780792236
# 70.02157139778137
# 70.02158498764038
# 70.02159810066223
# 70.02161169052124
# 70.02162551879883
# 70.02163887023926
# 70.02165269851685
# 70.02166628837585
# 70.02167963981628
# 70.02169394493103
# 70.0217080116272
# 70.02173614501953
# 70.0217502117157
# 70.02176451683044
# 70.02178049087524
# 70.02179861068726
# 70.02181124687195
# 70.0218231678009
# 70.02183651924133
# 70.02185010910034
# 70.02186322212219
# 70.02187657356262
# ...
